# %% [markdown]
# Pair programming Visualización
#
# Ejercicios visualización
#
# En este pair programming usaremos el csv que generamos en el pair programming de ayer, el de la gestión de nulos.
#  A lo largo de este ejercicio plantearemos una serie de preguntas que tendrás que contestar usando la visualización(podréis usar tanto Seaborn como Matplotlib).

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------
# ¿Cómo se distribuye la tasa de natalidad en el conjunto de datos?
#
# ¿Hay algún patrón evidente?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
pd.set_option('display.max_columns', None)
# Out:
# C:\Users\Isabel\AppData\Local\Temp\ipykernel_4656\840398369.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df_pair = pd.read_csv('world_data_full_apply_nulos.csv', index_col=0)

# %%
df_pair.columns
# Out:
# Index(['country', 'density', 'abbreviation', 'agricultural_land', 'land_area',
#        'armed_forces_size', 'birth_rate', 'calling_code', 'capital/major_city',
#        'co2-emissions', 'cpi', 'cpi_change', 'currency-code', 'fertility_rate',
#        'forested_area', 'gasoline_price', 'gdp',
#        'gross_primary_education_enrollment',
#        'gross_tertiary_education_enrollment', 'infant_mortality',
#        'largest_city', 'life_expectancy', 'maternal_mortality_ratio',
#        'minimum_wage', 'official_language', 'out_of_pocket_health_expenditure',
#        'physicians_per_thousand', 'population',
#        'population_labor_force_participation', 'tax_revenue', 'total_tax_rate',
#        'unemployment_rate', 'urban_population', 'latitude', 'longitude',
#        'continent'],
#       dtype='object')

# %%
df_pair.head()
# Out:
#        country  density abbreviation  agricultural_land  land_area  \
# 0  Afghanistan     60.0           AF               58.1    652.230
# 1      Albania    105.0           AL               43.1     28.748
# 2      Algeria     18.0           DZ               17.4        NaN
# 3      Andorra    164.0           AD               40.0    468.000
# 4       Angola     26.0           AO               47.5        NaN
#
#    armed_forces_size  birth_rate  calling_code capital/major_city  \
# 0              323.0       32.49          93.0              Kabul
# 1                9.0       11.78         355.0             Tirana
# 2              317.0       24.28         213.0            Algiers
# 3                NaN        7.20         376.0   Andorra la Vella
# 4              117.0       40.73         244.0             Luanda
#
#    co2-emissions     cpi  cpi_change currency-code  fertility_rate  \
# 0          8.672  149.90         2.3           AFN            4.47
# 1          4.536  119.05         1.4           ALL            1.62
# 2        150.006  151.36         2.0           DZD            3.02
# 3        469.000     NaN         NaN           EUR            1.27
# 4         34.693  261.73        17.1           AOA            5.52
#
#    forested_area  gasoline_price           gdp  \
# 0            2.1            0.70  1.910135e+10
# 1           28.1            1.36  1.527808e+10
# 2            0.8            0.28  1.699882e+11
# 3           34.0            1.51  3.154058e+09
# 4           46.3            0.97  9.463542e+10
#
#    gross_primary_education_enrollment  gross_tertiary_education_enrollment  \
# 0                               104.0                                  9.7
# 1                               107.0                                 55.0
# 2                               109.9                                 51.4
# 3                               106.4                                  NaN
# 4                               113.5                                  9.3
#
#    infant_mortality      largest_city  life_expectancy  \
# 0              47.9             Kabul             64.5
# 1               7.8            Tirana             78.5
# 2              20.1           Algiers             76.7
# 3               2.7  Andorra la Vella              NaN
# 4              51.6            Luanda             60.8
#
#    maternal_mortality_ratio  minimum_wage official_language  \
# 0                     638.0          0.43            Pashto
# 1                      15.0          1.12          Albanian
# 2                     112.0          0.95            Arabic
# 3                       NaN          6.63           Catalan
# 4                     241.0          0.71        Portuguese
#
#    out_of_pocket_health_expenditure  physicians_per_thousand  population  \
# 0                              78.4                     0.28         NaN
# 1                              56.9                     1.20         NaN
# 2                              28.1                     1.72         NaN
# 3                              36.4                     3.33      77.142
# 4                              33.4                     0.21         NaN
#
#    population_labor_force_participation  tax_revenue  total_tax_rate  \
# 0                                  48.9          9.3            71.4
# 1                                  55.7         18.6            36.6
# 2                                  41.2         37.2            66.1
# 3                                   NaN          NaN             NaN
# 4                                  77.5          9.2            49.1
#
#    unemployment_rate  urban_population   latitude  longitude continent
# 0              11.12               NaN  33.939110  67.709953      Asia
# 1              12.33               NaN  41.153332  20.168331    Europe
# 2              11.70               NaN  28.033886   1.659626    Africa
# 3                NaN            67.873  42.506285   1.521801    Europe
# 4               6.89               NaN -11.202692  17.873887    Africa

# %%
sns.histplot(x='birth_rate', data= df_pair, bins=20, kde=True)
plt.xlabel('Tasa natalidad')
plt.title('Distribución natalidad');

# %%
sns.boxplot(data= df_pair, x="birth_rate")
# Out:
# <Axes: xlabel='birth_rate'>

# %% [markdown]
# ## ¿Existe una relación aparente entre la tasa de mortalidad infantil y la esperanza de vida?
#
# Parecen ser inversamente proporcionales: a mayor esperanza de vida, menor mortalidad infantil

# %%
sns.scatterplot(x='infant_mortality', 
                y= 'life_expectancy', 
                data= df_pair, 
                color= 'violet')

plt.xlabel('Mortalidad Infantil')
plt.ylabel('Esperenza de vida')
plt.title('Mortalidad Infantil Vs Esperanza de vida')
# Out:
# Text(0.5, 1.0, 'Mortalidad Infantil Vs Esperanza de vida')

# %%
sns.regplot( x='infant_mortality', 
            y= 'life_expectancy', 
            data= df_pair, 
            color= 'orange', 
            marker= 'v')

plt.xlabel('Mortalidad Infantil')
plt.ylabel('Esperenza de vida')
plt.title('Mortalidad Infantil Vs Esperanza de vida')
# Out:
# Text(0.5, 1.0, 'Mortalidad Infantil Vs Esperanza de vida')

# %% [markdown]
# ## ¿Cuál es el continente con la mayor cantidad de países en el conjunto de datos?
#
# Proporciona el porcentaje de países en ese continente.

# %%
df_country= (df_pair.groupby('continent')['country'].count()/df_pair.shape[0]*100).reset_index()
df_country
# Out:
#          continent    country
# 0           Africa  27.179487
# 1             Asia  23.076923
# 2  Central America  10.256410
# 3           Europe  24.102564
# 4    North America   1.025641
# 5          Oceania   7.179487
# 6    South America   6.666667

# %%
colores = [ "mediumseagreen", "seagreen", "teal", "turquoise", "lightseagreen"]
plt.pie( df_country['country'], labels=df_country['continent'],
        data= df_country,
        autopct=  '%6.1f%%', 
        colors = colores, 
        textprops={'fontsize': 11}, 
        startangle=90)

plt.title('Porcentajes de paises por continente')
plt.gcf().set_size_inches(8,6)
plt.show()

# %%
sns.countplot(x = "continent", 
              data = df_pair, 
              palette = "viridis")

plt.xticks(rotation = 90)
# Out:
# C:\Users\Isabel\AppData\Local\Temp\ipykernel_4656\3283300776.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = "continent",
# ([0, 1, 2, 3, 4, 5, 6],
#  [Text(0, 0, 'Asia'),
#   Text(1, 0, 'Europe'),
#   Text(2, 0, 'Africa'),
#   Text(3, 0, 'Central America'),
#   Text(4, 0, 'South America'),
#   Text(5, 0, 'Oceania'),
#   Text(6, 0, 'North America')])

# %% [markdown]
# ## ¿Cuál es la mediana de la esperanza de vida en Europa?
#
# Proporciona un rango intercuartil aproximado y verifica si existen valores atípicos. s

# %%
sns.boxplot(y = "life_expectancy", 
            data = df_pair, 
            width = 0.5, 
            color = "turquoise")

plt.ylabel('Esperanza de vida')
# Out:
# Text(0, 0.5, 'Esperanza de vida')

# %%
print('Mediana de la esperanza de vida en Europa:', df_pair[df_pair['continent']=='Europe']['life_expectancy'].median())
q75, q25 = np.percentile(df_pair[df_pair['continent']=='Europe']['life_expectancy'].dropna(), [75, 25])
print(f'Rango: {q25}, {q75}')
print('No parece haber valores atípicos')
# Out:
# Mediana de la esperanza de vida en Europa: 80.9
# Rango: 76.3, 82.19999999999999
# No parece haber valores atípicos

# %% [markdown]
# ## ¿Existen relaciones visibles entre la tasa de natalidad y las siguientes variables: tasa de mortalidad infantil, esperanza de vida, densidad de población y población urbana?
#
# Tasa de natalidad vs Esperanza de vida: parecen ser inversamente proporcionales
# TdN vs Mortalidad infanti: parecen ser proporcionales
# TdN vs Densidad de población: parece haber una correlación negativa; esto llama la atención, ya que, por lógica, una mayor tasa de natalidad apuntaría a una mayor densidad de población. Quizá intervengan factores como la mortalidad
# TdN vs Población urbana: hay una correlación positiva

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 2, figsize = (20,10))

sns.scatterplot (x = 'birth_rate',
                y = 'life_expectancy',
                data= df_pair,
                marker = '*',
                color= 'orange',
                ax = axes[0][0])

axes[0][0].set_title('Tasa de natalidad vs. Esperanza de vida')
axes[0][0].set_xlabel('Tasa de natalidad')
axes[0][0].set_ylabel('Esperanza de vida')

sns.scatterplot( x= 'birth_rate',
                 y = 'infant_mortality',
                  data= df_pair,
                  markers= 'v',
                  color = 'red',
                  ax= axes[0][1])

axes[0][1].set_title('Tasa de natalidad vs. Mortalidad infantil')
axes[0][1].set_xlabel('Tasa de natalidad')
axes[0][1].set_ylabel('Tasa de mortalidad infantil')

sns.regplot( x= 'birth_rate',
                 y = 'density',
                  data= df_pair,
                  color = 'pink',
                  ax= axes[1][0])

axes[1][0].set_title('Tasa de natalidad vs. Densidad de población')
axes[1][0].set_xlabel('Tasa de natalidad')
axes[1][0].set_ylabel('Densidaad de población')

sns.regplot( x= 'birth_rate',
                 y = 'urban_population',
                  data= df_pair,
                  color = 'violet',
                  ax= axes[1][1])

axes[1][1].set_title('Tasa de natalidad vs. Población urbana')
axes[1][1].set_xlabel('Tasa de natalidad')
axes[1][1].set_ylabel('Población urbana');

# %% [markdown]
# ## ¿Cuáles son los 10 países con la mayor área forestal?

# %%
df_forestal= df_pair[['country', 'forested_area']].sort_values(by='forested_area', ascending = False).head(10)
df_forestal
# Out:
#                             country  forested_area
# 167                        Suriname           98.3
# 111  Federated States of Micronesia           91.9
# 61                            Gabon           90.0
# 154                      Seychelles           88.4
# 132                           Palau           87.6
# 71                           Guyana           83.9
# 92                             Laos           82.1
# 159                 Solomon Islands           77.9
# 135                Papua New Guinea           74.1
# 59                          Finland           73.1

# %%
sns.barplot(data = df_forestal, 
            x="forested_area", 
            y="country")
# Out:
# <Axes: xlabel='forested_area', ylabel='country'>

# %% [markdown]
# ## ¿Existen diferencias notables en la distribución de la tasa de natalidad entre continentes?

# %%
df_continent_nat = df_pair.groupby('continent')['birth_rate'].mean().reset_index()
df_continent_nat
# Out:
#          continent  birth_rate
# 0           Africa   31.906154
# 1             Asia   18.811136
# 2  Central America   16.689000
# 3           Europe    9.955111
# 4    North America   10.850000
# 5          Oceania   23.115833
# 6    South America   17.033077

# %%
sns.barplot(data =df_continent_nat, 
            x="birth_rate", 
            y="continent")
# Out:
# <Axes: xlabel='birth_rate', ylabel='continent'>

# %% [markdown]
# ## ¿Cómo se relacionan el CPI y el precio de la gasolina?
#
# Crea un scatter plot que muestre esta relación y agrega una línea para visualizar la tendencia.
#
# Ajusta los valores del CPI entre 100 y 300.

# %%
sns.regplot(x = "cpi", 
            y = "gasoline_price", 
            data = df_pair, 
            marker = "v")



plt.xlabel("Indices de precios")
plt.ylabel("Precio gasolina")
plt.xlim = ([100,300])
# ponemos título a la gráfica
plt.title("Relación entre el CPI y el precio de la gasolina");

# %% [markdown]
# ## ¿Cómo varía la esperanza de vida entre los diferentes países de Oceanía?
#
# Utiliza un diagrama de violín para representar la distribución de la esperanza de vida en función del idioma oficial de cada país.

# %%
df_oceania=df_pair[df_pair["continent"]=="Oceania"]
sns.violinplot(x="life_expectancy",
               y='official_language',
               data=df_oceania)
# Out:
# <Axes: xlabel='life_expectancy', ylabel='official_language'>
